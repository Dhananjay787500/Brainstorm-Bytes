# %%
s = "Python Programming is fun!"
# 1. How do you access the first character of a string using indexing?
s[0]
# Out:
# 'P'

# %%
# 2. How can you retrieve the last character of a string?
s[-1]
# Out:
# '!'

# %%
#3. Write the code to access the third character in the string "Python".
s[2]
# Out:
# 't'

# %%
# 4. How would you get the second last character of a string?
s[-2]
# Out:
# 'n'

# %%
# 5. What is the output of accessing the character at index 4 in "Python Programming"?
a = "Python Programming"
a[4]
# Out:
# 'o'

# %%
# 6. How do you retrieve the character at index 8?
a[8]
# Out:
# 'r'

# %%
# 7. Write the code to access the 10th character of the string.
a[10]
# Out:
# 'g'

# %%
# 8. How do you extract the first six characters of a string using slicing
a[:6]
# Out:
# 'Python'

# %%
# 9. Write the slicing expression to extract characters from index 7 to 11.
a[7:11]
# Out:
# 'Prog'

# %%
# 10. How can you get the last five characters of a string using slicing?
a[-5:]
# Out:
# 'mming'

# %%
# 11. Write the slicing expression to return the entire string.
a[:]
# Out:
# 'Python Programming'

# %%
# 12. How do you extract every second character from a string
a[1::2]
# Out:
# 'yhnPormig'

# %%
# 13. Write the slicing code to reverse a string.
a[::-1]
# Out:
# 'gnimmargorP nohtyP'

# %%
# 14. How do you extract the first 10 characters in reverse order
a[10::-1]
# Out:
# 'gorP nohtyP'

# %%
# 15. How can you exclude the first and last characters of a string using slicing?
a[1:-1]
# Out:
# 'ython Programmin'

# %%
# 16. Write the slicing expression to extract the middle segment of a string from index 3 to 13.
a[3:13]
# Out:
# 'hon Progra'

# %%
# 17. How do you get all characters from index 7 to the end of a string
a[7:]
# Out:
# 'Programming'

# %%
# 18. Write the slicing expression to extract the first half of a string.
b = len(a)/2
b
a[:9]
# Out:
# 'Python Pr'

# %%
# 19. How can you extract the second half of a string using slicing
a[9:]
# Out:
# 'ogramming'

# %%
# 19. Write the slicing code to get characters at even indices.
a[::2]
# Out:
# 'Pto rgamn'

# %%
# 20. How can you retrieve characters at odd indices of a string
a[::3]
# Out:
# 'Ph oai'

# %%
# 21. How do you extract characters between indices -10 and -5
a[-10:-5]
# Out:
# 'rogra'

# %%
# 22. Write the slicing code to reverse every second character of a string.
a[::2][::-1]
# Out:
# 'nmagr otP'

# %%
# 23. How can you repeat the first three characters of a string three times
a[:3]*3
# Out:
# 'PytPytPyt'

# %%
# 24. Write the slicing expression to exclude the first three and last three characters of a string.
char = a[3:-3]
print(char)
# Out:
# hon Programm

# %%
# 25. How do you reverse characters between the 4th and 9th indices
a[4:9][::-1]
# Out:
# 'rP no'

# %%
# 26. Write the slicing code to replace spaces in a string with underscores.
s = ''
for i in a:
    if i == ' ':
        s += '_'
    else:
        s += i
print(s)
# Out:
# Python_Programming

# %%
re = a.replace(' ', '_')
print(re)
# Out:
# Python_Programming
